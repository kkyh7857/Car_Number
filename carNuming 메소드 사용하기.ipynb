# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
plt.style.use('dark_background')

# %%
from opencv_module import carNumimg

# %%
for i in range(1, 300):
    carNumimg(i)
# Out:
# (2, '29버5924')
# (3, '16거9558')
# (4, '힙훑팠샌뺨뭄촬헵츠')
# (5, '16거9558')
# (6, '1거솜딥')
# (7, '흐')
# (8, '효375비7700')
# (9, '5바7700')
# (11, '끓1')
# (12, '55캇7538')
# (13, '셀557538')
# (14, '57햅7254')
# (15, '뚤1귈충출즈충7쇠납')
# (16, '53부3810')
# (17, '뺀뺀')
# (18, '21튼838')
# (19, '21튼381')
# (20, '271톨8381')
# (21, '271로8581')
# (22, '271로8381')
# (23, '07러4021')
# (24, '07리402캇')
# (25, '54조5720')
# (26, '54조5720')
# (27, '이브38481씰')
# (28, '어릿3')
# (29, '뭄230나280흐뭄')
# (30, '츠크쁘2웹죠')
# (31, '33무0476')
# (32, '뺀옌뺀')
# (33, '츠뺀꺄1')
# (34, '캇뺨믄겜훗촬촬')
# (35, '끓이딥야뭄0')
# (36, '86섭')
# (37, '0디흘')
# (38, '뭄숟띠')
# (39, '덴촬머8664크')
# (40, '댄종머866뻔')
# (41, '0908664')
# (42, '뺀찢팠그')
# (43, '끓끓씰겜')
# (44, '찢웹덩1314')
# (45, '그솜팎7374')
# (46, '38구7374')
# (47, '38구7374')
# (48, '')
# (49, '붓촬흐짚혹솝호4')
# (50, '34리6644')
# (52, '34리6644')
# (53, '34웹6644')
# (54, '32햅1380')
# (55, '32햅1380')
# (56, '32다1380')
# (57, '핸138꼬그1')
# (58, '효따끓0큭')
# (59, '끄6도츰윌1웹')
# (60, '갤뜸16두621겜')
# (62, '68촬웜53떳')
# ...

# %%
carNumimg(1)
